# %% [markdown]
# <a href="https://colab.research.google.com/github/unatisaini/flyrank-internship-ml/blob/main/work/notebooks/w01_research_question.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# # ML-02 — Research Question and Provisional Lane
#
# [![Open In Colab](https://colab.research.google.com/assets/colab-badge.svg)](https://colab.research.google.com/github/Sagnik556/flyrank-ml-internship-starter/blob/main/work/notebooks/w01_research_question.ipynb)
#
# This skeleton is yours to fill. Work the sections **in order** — each one has a one-line hint. Simple words, honest numbers.
#
# > Working with an AI assistant? Tell it to read `skills/README.md` first and load the one skill this assignment names on its card.

# %%
import os

# Clone the repository to access the data files
repo_name = 'flyrank-ml-internship-starter'
if not os.path.exists(repo_name):
    # !git clone https://github.com/Sagnik556/flyrank-ml-internship-starter.git
else:
    print(f"Repository '{repo_name}' already exists.")
# Out:
# Cloning into 'flyrank-ml-internship-starter'...
# remote: Enumerating objects: 226, done.
# remote: Counting objects: 100% (137/137), done.
# remote: Compressing objects: 100% (55/55), done.
# remote: Total 226 (delta 107), reused 82 (delta 82), pack-reused 89 (from 1)
# Receiving objects: 100% (226/226), 1.84 MiB | 8.90 MiB/s, done.
# Resolving deltas: 100% (114/114), done.

# %% [markdown]
# ## 1. My lane (or freestyle) and why
#
# *Name your lane — or say 'freestyle' and describe your own question. One short paragraph: why this one?*

# %% [markdown]
# I'm picking Lane 4: CTR/Engagement Opportunity Scoring. It produces a ranked, actionable output rather than an open-ended correlation report, and the baseline — expected CTR by position tier — is transparent and easy to defend with real numbers from week one

# %% [markdown]
# 2. The question: decision, action, cost of a wrong call
#
# *What decision does your work improve? Who acts on it? What does a wrong recommendation cost?*

# %% [markdown]
# Research question: Which visible pages under-capture clicks or engagement relative to their position tier, and deserve metadata, content, or monitoring review?
# Unit of analysis: one page (content item) per row.
# Decision: which pages a reviewer prioritizes this cycle.
# Action: rewrite title/meta, improve intent match, improve snippet structure, improve on-page engagement, or monitor.
# Cost of a wrong call: wasted rewrite effort on a page whose low CTR is just noise, while a real underperformer goes unreviewed.

# %% [markdown]
# ## 3. Quick look at the data (2-3 real numbers)
#
# *Load the starter CSV below and show 2-3 real numbers that make your lane look worth the next 7 weeks.*

# %%
# !git clone https://github.com/unatisaini/flyrank-internship-ml.git
# %cd flyrank-internship-ml
# Out:
# Cloning into 'flyrank-internship-ml'...
# remote: Enumerating objects: 132, done.
# remote: Counting objects: 100% (132/132), done.
# remote: Compressing objects: 100% (88/88), done.
# remote: Total 132 (delta 45), reused 94 (delta 28), pack-reused 0 (from 0)
# Receiving objects: 100% (132/132), 1.85 MiB | 9.58 MiB/s, done.
# Resolving deltas: 100% (45/45), done.
# /content/flyrank-internship-ml/flyrank-internship-ml/flyrank-internship-ml

# %%
import pandas as pd
df = pd.read_csv("data/raw/content_refresh_anonymized.csv")
for col in df.columns:
    print(col)
# Out:
# content_id
# client_id
# search_volume
# competition
# competition_level
# cpc
# content_type
# main_intent
# word_count
# char_count
# provider_used
# model_used
# impressions_90d
# clicks_90d
# pageviews_90d
# sessions_90d
# users_90d
# engaged_sessions_90d
# ai_sessions_90d
# scroll_events_90d
# days_with_impressions
# days_with_sessions
# impressions_last_30d
# clicks_last_30d
# sessions_last_30d
# impressions_prev_30d
# clicks_prev_30d
# sessions_prev_30d
# content_age_days
# age_tier
# age_tier_order
# days_since_last_update
# freshness_tier
# word_count_tier
# char_count_tier
# ctr
# avg_position
# engagement_rate
# scroll_rate
# ai_traffic_pct
# impression_tier
# position_tier
# trend_direction
# trend_pct

# %% [markdown]
# ## 4. Careful words: what I can and can't claim
#
# *Write what your work will be able to say (observed, directional, decision-support) — and what it never will (causal proof, 'predicting Google').*

# %% [markdown]
# This is observational, not experimental — I'm identifying association between position tier and CTR, not proving causation. A low CTR gap flags a candidate for review, not a confirmed problem. I'm not claiming to have reverse-engineered any Google ranking factor.

# %% [markdown]
# ## Self-check
#
# Before you submit, confirm each line honestly:
#
# - [ ] Every section above is filled — markdown thinking AND the code that backs it
# - [ ] The notebook runs top to bottom with no errors (Runtime → Run all)
# - [ ] No client names, URLs, or private queries anywhere
# - [ ] My claims use careful words: observed, measured, directional, decision-support
# - [ ] Committed to my repo under `work/notebooks/` — then submit your repo URL on the card. Done.
